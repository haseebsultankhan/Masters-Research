# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::sphinx==3.5.1=pyhd3eb1b0_0
#   - defaults/linux-64::scikit-image==0.17.2=py37hdf5156a_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/linux-64::secretstorage==3.3.1=py37h06a4308_0
#   - defaults/linux-64::conda==4.8.4=py37_0
#   - defaults/linux-64::scikit-learn==0.23.2=py37h0573a6f_0
#   - defaults/linux-64::spyder==4.2.1=py37h06a4308_1
#   - defaults/linux-64::_anaconda_depends==2020.07=py37_0
#   - defaults/linux-64::anaconda-client==1.7.2=py37_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/linux-64::scipy==1.6.1=py37h91f5cce_0
#   - defaults/linux-64::statsmodels==0.12.2=py37h27cfd23_0
#   - defaults/linux-64::keyring==22.0.1=py37h06a4308_0
#   - defaults/linux-64::patsy==0.5.1=py37_0
# ...

# %%
conda install -c conda-forge r-feather
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - r-feather
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-1.2.2          |     pyhd8ed1ab_0          40 KB  conda-forge
#     aiohttp-3.7.3              |   py36h8f6f2f9_2         629 KB  conda-forge
#     astroid-2.5                |   py36h5fab9bb_1         297 KB  conda-forge
# ...

# %%
pip install feather-format
# Out:
# ...
#   Created wheel for feather-format: filename=feather_format-0.4.1-py3-none-any.whl size=2453 sha256=dc5c8aa528835be09cd3d3997207745da16e2d55c035f9febccf2390fb7e9325
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/9d/90/64/88411837e80bb520d15ae395f39359a5413e7a00ae63397e10
# Successfully built feather-format
# WARNING: Error parsing requirements for urllib3: [Errno 2] No such file or directory: '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3-1.26.4.dist-info/METADATA'
# WARNING: Error parsing requirements for lxml: [Errno 2] No such file or directory: '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/lxml-4.6.3.dist-info/METADATA'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sagemaker
import boto3
import seaborn as sns 
sns.set()
sns.set_style("white")
sns.set_context("paper")
sns.set_palette("Set2")
import matplotlib.pyplot as plt 
import feather

# %%
pip install cufflinks
# Out:
# ...
#      |████████████████████████████████| 81 kB 10.3 MB/s eta 0:00:01
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67922 sha256=53307623a74541f36b99b07fdfc12e803c66ac3db0fe83b75d87cf0c04b2c0a6
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/1c/db/ce/70cf35eb5a61b9ea3d34434072a8821dddc4f21eb5127e5415
# Successfully built cufflinks
# WARNING: Error parsing requirements for urllib3: [Errno 2] No such file or directory: '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3-1.26.4.dist-info/METADATA'
# WARNING: Error parsing requirements for lxml: [Errno 2] No such file or directory: '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/lxml-4.6.3.dist-info/METADATA'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display, HTML
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import sagemaker
import boto3
client = boto3.client('s3')
path_A = 's3://haseebdata/EDNET DATA/ednet.ftr'

# %%
path_B = 's3://haseebdata/EDNET DATA/questions.csv'
path_C = 's3://haseebdata/EDNET DATA/lectures.csv'
path_D = 's3://haseebdata/EDNET DATA/payments.csv'
path_E = 's3://haseebdata/EDNET DATA/coupons.csv'

# %%
df = pd.read_feather(path_A)

# %%
df['action_type'].unique()
# Out:
# array([None, 'enter', 'respond', 'submit', 'play_video', 'pause_video',
#        'quit', 'play_audio', 'pause_audio', 'pay', 'erase_choice',
#        'undo_erase_choice', 'refund', 'enroll_coupon'], dtype=object)

# %%
pd.value_counts(df['action_type'], dropna=False)

# %%
df['user_answer'].unique()
# Out:
# array(['b', 'c', 'a', 'd', None], dtype=object)

# %%
questions = pd.read_csv(path_B)
lectures = pd.read_csv(path_C)
payments = pd.read_csv(path_D)
coupons = pd.read_csv(path_E)

# %%
pd.set_option('display.max_columns',None)

# %%
df[0:100]
# Out:
#         timestamp  solving_id question_id user_answer  elapsed_time  user_iD  \
# 0   1565096190868         1.0       q5012           b       38000.0        1
# 1   1565096221062         2.0       q4706           c       24000.0        1
# 2   1565096293432         3.0       q4366           b       68000.0        1
# 3   1565096339668         4.0       q4829           a       42000.0        1
# 4   1565096401774         5.0       q6528           b       59000.0        1
# ..            ...         ...         ...         ...           ...      ...
# 95  1566027677787        86.0       q6923           b       49750.0        1
# 96  1566219014693        87.0       q5724           b       35000.0        1
# 97  1566219099863        88.0       q8557           d       58000.0        1
# 98  1566219161537        89.0       q3939           c       32000.0        1
# 99  1566219216118        90.0       q8482           a       33000.0        1
#
# ...

# %%
df[20000:20050]
# Out:
#            timestamp  solving_id question_id user_answer  elapsed_time  \
# 20000  1567638668447       464.0       q8873           b       16000.0
# 20001  1567638731462       465.0       q4424           a       10000.0
# 20002  1567638765399       466.0       q6738           c        8000.0
# 20003  1567638828019       467.0       q6163           c       27000.0
# 20004  1567638883708       468.0       q9092           c       36000.0
# 20005  1567638954925       469.0       q4318           d       19000.0
# 20006  1567639005357       470.0       q6523           b       13000.0
# 20007  1567639021030       471.0       q5020           a        4000.0
# 20008  1567639124078       472.0       q9468           a        8000.0
# 20009  1567640394886       473.0       q1112           a       19000.0
# 20010  1567640430794       474.0        q404           b       20000.0
# 20011  1567640467443       475.0        q537           c       18000.0
# ...

# %%
df.dtypes
# Out:
# timestamp         int64
# solving_id      float64
# question_id      object
# user_answer      object
# elapsed_time    float64
# user_iD           int64
# action_type      object
# item_id          object
# cursor_time     float64
# source           object
# platform         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162663926 entries, 0 to 162663925
# Data columns (total 11 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   timestamp     int64
#  1   solving_id    float64
#  2   question_id   object
#  3   user_answer   object
#  4   elapsed_time  float64
#  5   user_iD       int64
#  6   action_type   object
#  7   item_id       object
#  8   cursor_time   float64
#  9   source        object
#  10  platform      object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 13.3+ GB

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# elapsed_time    131375195
# question_id     131375195
# solving_id      131375195
# cursor_time     125395358
# user_answer     103176580
# platform         31316664
# source           31316664
# item_id          31288731
# action_type      31288731
# user_iD                 0
# timestamp               0
# dtype: int64

# %%
low_memory=False
ax = sns.heatmap(df.isnull(), cbar = False, cmap = 'Blues')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-8ada852bb2f9> in <module>
#       1 low_memory=False
# ----> 2 ax = sns.heatmap(df.isnull(), cbar = False, cmap = 'Blues')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
corr = df.corr()
plt.figure(figsize=(15,6))
sns.heatmap(corr, annot=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-26-932cbed222f9> in <module>
# ----> 1 corr = df.corr()
#       2 plt.figure(figsize=(15,6))
#       3 sns.heatmap(corr, annot=True)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in corr(self, method, min_periods)
#    8128         cols = numeric_df.columns
#    8129         idx = cols.copy()
# -> 8130         mat = numeric_df.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    8131
#    8132         if method == "pearson":
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1370         self._consolidate_inplace()
#    1371         result = self._mgr.as_array(
# -> 1372             transpose=self._AXIS_REVERSED, dtype=dtype, copy=copy, na_value=na_value
#    1373         )
# ...

# %%
questions.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#      deployed_at
# 0  1558093217098
# 1  1558093219720
# 2  1558093222784
# 3  1558093225357
# 4  1558093228439

# %%
questions.dtypes
# Out:
# question_id       object
# bundle_id         object
# explanation_id    object
# correct_answer    object
# part               int64
# tags              object
# deployed_at        int64
# dtype: object

# %%
lectures.head()
# Out:
#   lecture_id  part  tags  video_length    deployed_at
# 0       l520     5   142            -1             -1
# 1       l592     6   142            -1             -1
# 2      l1259     1   222        359000  1570424729123
# 3      l1260     1   220        487000  1570424738105
# 4      l1261     1   221        441000  1570424743162

# %%
column_1 = df['user_answer']
column_2 = questions['correct_answer']

# %%
column_1.sort_index(inplace = True)
column_2.sort_index(inplace = True)

# %%
low_memory=False
comparison_column = np.where(column_1.sort_index().sort_index(axis=1) == column_2.sort_index().sort_index(axis=1), True, False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-47-16c5de46621a> in <module>
#       1 low_memory=False
# ----> 2 comparison_column = np.where(column_1.sort_index().sort_index(axis=1) == column_2.sort_index().sort_index(axis=1), True, False)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    3488                     return
#    3489                 else:
# -> 3490                     return self.copy()
#    3491
#    3492             indexer = nargsort(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    5663         dtype: object
#    5664         """
# -> 5665         data = self._mgr.copy(deep=deep)
#    5666         self._clear_item_cache()
# ...

# %%
low_memory=False
comparison_column = np.where(column_1.sort_index() == column_2.sort_index(), True, False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-49-ac5cc1704c07> in <module>
#       1 low_memory=False
# ----> 2 comparison_column = np.where(column_1.sort_index() == column_2.sort_index(), True, False)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    3488                     return
#    3489                 else:
# -> 3490                     return self.copy()
#    3491
#    3492             indexer = nargsort(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    5663         dtype: object
#    5664         """
# -> 5665         data = self._mgr.copy(deep=deep)
#    5666         self._clear_item_cache()
# ...

# %%
correlation = column_1.corr(column_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-157a9a5b18d4> in <module>
# ----> 1 correlation = column_1.corr(column_2)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2333         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2334             return nanops.nancorr(
# -> 2335                 this.values, other.values, method=method, min_periods=min_periods
#    2336             )
#    2337
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ...

# %%
df['user_answer'].corr(questions['correct_answer'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-cbf991e0ba1e> in <module>
# ----> 1 df['user_answer'].corr(questions['correct_answer'])
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2333         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2334             return nanops.nancorr(
# -> 2335                 this.values, other.values, method=method, min_periods=min_periods
#    2336             )
#    2337
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
# ...

# %%
comparison_column = np.where(df["user_answer"] == questions["correct_answer"], True, False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-59bc134c4e97> in <module>
# ----> 1 comparison_column = np.where(df["user_answer"] == questions["correct_answer"], True, False)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     363
#     364         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 365             raise ValueError("Can only compare identically-labeled Series objects")
#     366
#     367         lvalues = extract_array(self, extract_numpy=True)
#
# ...

# %%
from pandas.testing import assert_frame_equal

# %%
assert_frame_equal(column_1.reset_index(drop=True), column_2.reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-53-bab2103c057b> in <module>
# ----> 1 assert_frame_equal(column_1.reset_index(drop=True), column_2.reset_index(drop=True))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in reset_index(self, level, drop, name, inplace)
#    1295             else:
#    1296                 return self._constructor(
# -> 1297                     self._values.copy(), index=new_index
#    1298                 ).__finalize__(self, method="reset_index")
#    1299         elif inplace:
#
# MemoryError: Unable to allocate 1.21 GiB for an array with shape (162663926,) and data type object

# %%
len(df['user_answer'])
# Out:
# 162663926

# %%
df['user_answer'].isnull().sum()
# Out:
# 103176580

# %%
len(questions['correct_answer'])
# Out:
# 13169

# %%
df['user_answer'] = df['user_answer'].replace(np.nan, 0)
