# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sagemaker
import boto3
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns',None) # To display all columns
pd.set_option('display.max_rows',None) # To display all columns
client = boto3.client('s3')
import feather
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from functools import reduce

# %%
Data60k = pd.read_csv('data_60K.csv')
Data3lac = pd.read_csv('data_3lac.csv')

# %%
Data60k.head()

# %%
Data60k.Percentage = Data60k.Percentage.round()

# %%
Data60k.head()
# Out:
#    Unnamed: 0  user_iD  Total Questions Attempted  Corrected  Incorrected  \
# 0           0        1                       1082        753          329
# 1           1       10                         16          9            7
# 2           2      100                         33         18           15
# 3           3     1000                       1488        930          558
# 4           4    10004                       2486       1790          696
#
#    Percentage  elapsed_time
# 0        70.0         36.75
# 1        56.0         27.75
# 2        55.0         34.50
# 3        62.0         34.00
# 4        72.0         25.00

# %%
Data60k.elapsed_time = Data60k.elapsed_time.round()
Data60k.head()
# Out:
#    user_iD  Total Questions Attempted  Corrected  Incorrected  Percentage  \
# 0        1                       1082        753          329        70.0
# 1       10                         16          9            7        56.0
# 2      100                         33         18           15        55.0
# 3     1000                       1488        930          558        62.0
# 4    10004                       2486       1790          696        72.0
#
#    elapsed_time
# 0          37.0
# 1          28.0
# 2          34.0
# 3          34.0
# 4          25.0

# %%
Data3lac.Percentage = Data3lac.Percentage.round() 
Data3lac.elapsed_time = Data3lac.elapsed_time.round()
del Data3lac['Unnamed: 0']
Data3lac.head()
# Out:
#    user_iD  Total Questions Attempted  Corrected  Incorrected  Percentage  \
# 0        1                       1082        753          329        70.0
# 1       10                         16          9            7        56.0
# 2      100                         33         18           15        55.0
# 3     1000                       1488        930          558        62.0
# 4    10004                       2486       1790          696        72.0
#
#    elapsed_time
# 0          37.0
# 1          28.0
# 2          34.0
# 3          34.0
# 4          25.0
