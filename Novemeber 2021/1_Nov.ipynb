# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import sagemaker
#import boto3
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns',None) # To display all columns
pd.set_option('display.max_rows',None) # To display all columns
#client = boto3.client('s3')
import feather
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from functools import reduce

# %%
df = pd.read_feather('C:/Users/PC1/Desktop/DATASET/EDNET.ftr')
dfq = pd.read_feather('C:/Users/PC1/Desktop/DATASET/dfq.ftr')
Users = pd.read_feather('C:/Users/PC1/Desktop/DATASET/Users.ftr')

# %%
df.head()
# Out:
#        timestamp  solving_id  question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1         5012           b         38000        1
# 1  1565096221062           2         4706           c         24000        1
# 2  1565096293432           3         4366           b         68000        1
# 3  1565096339668           4         4829           a         42000        1
# 4  1565096401774           5         6528           b         59000        1
#
#   correct_answer  bundle_id  explanation_id  part tags  \
# 0              c       3544            3544     5   74
# 1              c       3238            3238     5   71
# 2              b       2898            2898     5  103
# 3              c       3361            3361     5   83
# 4              d       5060            5060     5   90
#
#               deployed_at  correct
# 0 2019-09-17 02:43:28.616      0.0
# 1 2019-10-30 05:34:30.723      1.0
# 2 2019-10-30 05:37:51.451      1.0
# ...

# %%
df['elapsed_time']= df.elapsed_time.div(1000)
del df['part']
del df['tags']

# %%
df.head()
# Out:
#        timestamp  solving_id  question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1         5012           b          38.0        1
# 1  1565096221062           2         4706           c          24.0        1
# 2  1565096293432           3         4366           b          68.0        1
# 3  1565096339668           4         4829           a          42.0        1
# 4  1565096401774           5         6528           b          59.0        1
#
#   correct_answer  bundle_id  explanation_id             deployed_at  correct
# 0              c       3544            3544 2019-09-17 02:43:28.616      0.0
# 1              c       3238            3238 2019-10-30 05:34:30.723      1.0
# 2              b       2898            2898 2019-10-30 05:37:51.451      1.0
# 3              c       3361            3361 2019-06-24 09:24:51.347      0.0
# 4              d       5060            5060 2019-10-17 03:03:15.009      0.0

# %%
df.to_feather('Dataset.ftr')

# %%
df = pd.read_feather('Dataset.ftr')

# %%
df.head()
# Out:
#        timestamp  solving_id  question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1         5012           b          38.0        1
# 1  1565096221062           2         4706           c          24.0        1
# 2  1565096293432           3         4366           b          68.0        1
# 3  1565096339668           4         4829           a          42.0        1
# 4  1565096401774           5         6528           b          59.0        1
#
#   correct_answer  bundle_id  explanation_id             deployed_at  correct
# 0              c       3544            3544 2019-09-17 02:43:28.616      0.0
# 1              c       3238            3238 2019-10-30 05:34:30.723      1.0
# 2              b       2898            2898 2019-10-30 05:37:51.451      1.0
# 3              c       3361            3361 2019-06-24 09:24:51.347      0.0
# 4              d       5060            5060 2019-10-17 03:03:15.009      0.0

# %%
df.dtypes
# Out:
# timestamp                  int64
# solving_id                 int64
# question_id                int32
# user_answer               object
# elapsed_time             float64
# user_iD                    int32
# correct_answer            object
# bundle_id                  int32
# explanation_id             int32
# deployed_at       datetime64[ns]
# correct                  float64
# dtype: object

# %%
df_2 = df.sort_values(['user_iD', 'timestamp'], ascending=[True, False], inplace=True)

# %%
df_2[0:20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3a06e9401f55> in <module>
# ----> 1 df_2[0:20]
#
# TypeError: 'NoneType' object is not subscriptable
