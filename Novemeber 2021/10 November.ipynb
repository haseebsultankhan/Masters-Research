# %%
import pandas as pd
import numpy as np
import seaborn as sns
#import sagemaker
#import boto3
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns',None) # To display all columns
pd.set_option('display.max_rows',None) # To display all columns
#client = boto3.client('s3')
import feather
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from functools import reduce

# %%
df= pd.read_feather('Dataset.ftr')

# %%
Users = pd.read_feather('C:/Users/PC1/Desktop/DATASET/Users.ftr')

# %%
df.head()
# Out:
#        timestamp  solving_id  question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1         5012           b          38.0        1
# 1  1565096221062           2         4706           c          24.0        1
# 2  1565096293432           3         4366           b          68.0        1
# 3  1565096339668           4         4829           a          42.0        1
# 4  1565096401774           5         6528           b          59.0        1
#
#   correct_answer  bundle_id  explanation_id             deployed_at  correct
# 0              c       3544            3544 2019-09-17 02:43:28.616      0.0
# 1              c       3238            3238 2019-10-30 05:34:30.723      1.0
# 2              b       2898            2898 2019-10-30 05:37:51.451      1.0
# 3              c       3361            3361 2019-06-24 09:24:51.347      0.0
# 4              d       5060            5060 2019-10-17 03:03:15.009      0.0

# %%
Users.head()
# Out:
#    user_iD  Total Questions Attempted  Corrected  Incorrected  Percentage  \
# 0        1                       1082        753          329   69.593346
# 1       10                         16          9            7   56.250000
# 2      100                         33         18           15   54.545455
# 3     1000                       1488        930          558   62.500000
# 4    10000                        405        258          147   63.703704
#
#    elapsed_time
# 0         36.75
# 1         27.75
# 2         34.50
# 3         34.00
# 4         25.00

# %%
df.sort_values(by=['user_iD', 'timestamp'], ascending=True, inplace=True)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
hist = df['user_iD' , 'timestamp'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('user_iD', 'timestamp')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d0824aea1aea> in <module>
# ...

# %%
df['user_iD'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Users['Percentage'] = Users['Percentage'].apply(np.ceil)

# %%
Users.head()
# Out:
#    user_iD  Total Questions Attempted  Corrected  Incorrected  Percentage  \
# 0        1                       1082        753          329        70.0
# 1       10                         16          9            7        57.0
# 2      100                         33         18           15        55.0
# 3     1000                       1488        930          558        63.0
# 4    10000                        405        258          147        64.0
#
#    elapsed_time
# 0         36.75
# 1         27.75
# 2         34.50
# 3         34.00
# 4         25.00

# %%
Users[0:50]
# Out:
#     user_iD  Total Questions Attempted  Corrected  Incorrected  Percentage  \
# 0         1                       1082        753          329        70.0
# 1        10                         16          9            7        57.0
# 2       100                         33         18           15        55.0
# 3      1000                       1488        930          558        63.0
# 4     10000                        405        258          147        64.0
# 5    100001                         33         15           18        46.0
# 6    100002                        250        185           65        74.0
# 7    100003                         30         11           19        37.0
# 8    100004                         30         17           13        57.0
# 9    100005                       3436       2410         1026        71.0
# 10   100006                          8          7            1        88.0
# ...

# %%
sorted_df = Users.sort_values(by=['user_iD'], ascending=True)

# %%
sorted_df[0:50]
# Out:
#         user_iD  Total Questions Attempted  Corrected  Incorrected  \
# 0             1                       1082        753          329
# 103211        2                       1103        765          338
# 205341        3                         10          3            7
# 305985        4                       2699       1932          767
# 408468        5                       1233        754          479
# 598361        7                       1249        808          441
# 672844        8                         13          7            6
# 713582        9                        171         78           93
# 1            10                         16          9            7
# 10511        11                       4681       3224         1457
# 20722        12                         59         31           28
# 31066        13                         59         33           26
# 41317        14                        196        121           75
# ...
