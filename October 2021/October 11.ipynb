# %%
import pandas as pd
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns',None) # To display all columns
pd.set_option('display.max_rows',None) # To display all columns
import feather
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from functools import reduce
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df =pd.read_csv('C:/Users/PC1/Desktop/DATASET/EDNET.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      timestamp  solving_id question_id user_answer  \
# 0           0  1565096190868           1       q5012           b
# 1           1  1565096221062           2       q4706           c
# 2           2  1565096293432           3       q4366           b
# 3           3  1565096339668           4       q4829           a
# 4           4  1565096401774           5       q6528           b
#
#    elapsed_time  user_iD correct_answer  bundle_id  explanation_id  part tags  \
# 0         38000        1              c       3544            3544     5   74
# 1         24000        1              c       3238            3238     5   71
# 2         68000        1              b       2898            2898     5  103
# 3         42000        1              c       3361            3361     5   83
# 4         59000        1              d       5060            5060     5   90
#
#                deployed_at  correct
# 0  2019-09-17 02:43:28.616      0.0
# ...

# %%
df.question_id = df.question_id.str.slice(start=1)

# %%
del df['Unnamed: 0']
df.head()
# Out:
#        timestamp  solving_id question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1        5012           b         38000        1
# 1  1565096221062           2        4706           c         24000        1
# 2  1565096293432           3        4366           b         68000        1
# 3  1565096339668           4        4829           a         42000        1
# 4  1565096401774           5        6528           b         59000        1
#
#   correct_answer  bundle_id  explanation_id  part tags  \
# 0              c       3544            3544     5   74
# 1              c       3238            3238     5   71
# 2              b       2898            2898     5  103
# 3              c       3361            3361     5   83
# 4              d       5060            5060     5   90
#
#                deployed_at  correct
# 0  2019-09-17 02:43:28.616      0.0
# 1  2019-10-30 05:34:30.723      1.0
# 2  2019-10-30 05:37:51.451      1.0
# ...

# %%
#df.question_id = df.question_id.str.slice(start=1)
#df.bundle_id = df.bundle_id.str.slice(start=1)
#df.explanation_id = df.explanation_id.str.slice(start=1)
df['elapsed_time']= df.elapsed_time.div(1000)

# %%
df[df['question_id'].notnull()]

# %%
df.head()
# Out:
# ERROR! Session/line number was not unique in
#        timestamp  solving_id question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868           1         012           b          38.0        1
# 1  1565096221062           2         706           c          24.0        1
# 2  1565096293432           3         366           b          68.0        1
# 3  1565096339668           4         829           a          42.0        1
# 4  1565096401774           5         528           b          59.0        1
#
#   correct_answer  bundle_id  explanation_id  part tags  \
# 0              c       3544            3544     5   74
# 1              c       3238            3238     5   71
# 2              b       2898            2898     5  103
# 3              c       3361            3361     5   83
# 4              d       5060            5060     5   90
#
#                deployed_at  correct
# 0  2019-09-17 02:43:28.616      0.0
# 1  2019-10-30 05:34:30.723      1.0
# ...
