# %%
import pandas as pd
import numpy as np
import boto3
import feather

# %%
client = boto3.client('s3')

# %%
PathA = 's3://haseebdata/EDNET DATA/ednet.ftr'
PathB = 's3://haseebdata/EDNET DATA/KT1.ftr'
PathC = 's3://haseebdata/EDNET DATA/KT4.ftr'

# %%
PathD = 's3://haseebdata/EDNET DATA/questions.csv'
PathE = 's3://haseebdata/EDNET DATA/lectures.csv'

# %%
EdNet = pd.read_feather(PathA)
KT1 = pd.read_feather(PathB)
KT4 = pd.read_feather(PathC)

# %%
questions = pd.read_csv(PathD)
lectures = pd.read_csv(PathE)

# %%
EdNet.head()
# Out:
#        timestamp  solving_id question_id user_answer  elapsed_time  user_iD  \
# 0  1565096190868         1.0       q5012           b       38000.0        1
# 1  1565096221062         2.0       q4706           c       24000.0        1
# 2  1565096293432         3.0       q4366           b       68000.0        1
# 3  1565096339668         4.0       q4829           a       42000.0        1
# 4  1565096401774         5.0       q6528           b       59000.0        1
#
#   action_type item_id  cursor_time source platform
# 0        None    None          NaN   None     None
# 1        None    None          NaN   None     None
# 2        None    None          NaN   None     None
# 3        None    None          NaN   None     None
# 4        None    None          NaN   None     None

# %%
KT1.head()
# Out:
#        timestamp  solving_id question_id user_answer  elapsed_time  user_iD
# 0  1565096190868           1       q5012           b         38000        1
# 1  1565096221062           2       q4706           c         24000        1
# 2  1565096293432           3       q4366           b         68000        1
# 3  1565096339668           4       q4829           a         42000        1
# 4  1565096401774           5       q6528           b         59000        1

# %%
KT4.head()
# Out:
#        timestamp action_type item_id  cursor_time     source user_answer  \
# 0  1565096151269       enter   b3544          NaN  diagnosis        None
# 1  1565096187972     respond   q5012          NaN  diagnosis           b
# 2  1565096194904      submit   b3544          NaN  diagnosis        None
# 3  1565096195001       enter   b3238          NaN  diagnosis        None
# 4  1565096218682     respond   q4706          NaN  diagnosis           c
#
#   platform  user_iD
# 0   mobile        1
# 1   mobile        1
# 2   mobile        1
# 3   mobile        1
# 4   mobile        1

# %%
EdNet.shape
# Out:
# (162663926, 11)

# %%
KT1.shape
# Out:
# (31288731, 6)

# %%
KT2.shape
# Out:
# (131375195, 8)

# %%
questions.shape
# Out:
# (13169, 7)

# %%
questions.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#      deployed_at
# 0  1558093217098
# 1  1558093219720
# 2  1558093222784
# 3  1558093225357
# 4  1558093228439

# %%
lectures.shape
# Out:
# (1021, 5)

# %%
lectures.head()
# Out:
#   lecture_id  part  tags  video_length    deployed_at
# 0       l520     5   142            -1             -1
# 1       l592     6   142            -1             -1
# 2      l1259     1   222        359000  1570424729123
# 3      l1260     1   220        487000  1570424738105
# 4      l1261     1   221        441000  1570424743162

# %%
import json
from datetime import datetime

# %%
questions['deployed_at'] = pd.to_datetime(questions['deployed_at'],unit='ms')

# %%
questions.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#               deployed_at
# 0 2019-05-17 11:40:17.098
# 1 2019-05-17 11:40:19.720
# 2 2019-05-17 11:40:22.784
# 3 2019-05-17 11:40:25.357
# 4 2019-05-17 11:40:28.439

# %%
lectures['deployed_at'] = pd.to_datetime(lectures['deployed_at'],unit='ms')

# %%
lectures.head()
# Out:
#   lecture_id  part  tags  video_length             deployed_at
# 0       l520     5   142            -1 1969-12-31 23:59:59.999
# 1       l592     6   142            -1 1969-12-31 23:59:59.999
# 2      l1259     1   222        359000 2019-10-07 05:05:29.123
# 3      l1260     1   220        487000 2019-10-07 05:05:38.105
# 4      l1261     1   221        441000 2019-10-07 05:05:43.162

# %%
KT1['timestamp'] = pd.to_datetime(KT1['timestamp'],unit='ms')
KT1.head()
# Out:
#                 timestamp  solving_id question_id user_answer  elapsed_time  \
# 0 2019-08-06 12:56:30.868           1       q5012           b         38000
# 1 2019-08-06 12:57:01.062           2       q4706           c         24000
# 2 2019-08-06 12:58:13.432           3       q4366           b         68000
# 3 2019-08-06 12:58:59.668           4       q4829           a         42000
# 4 2019-08-06 13:00:01.774           5       q6528           b         59000
#
#    user_iD
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
KT4['timestamp'] = pd.to_datetime(KT1['timestamp'],unit='ms')
KT4.head()
# Out:
#                 timestamp action_type item_id  cursor_time     source  \
# 0 2019-08-06 12:56:30.868       enter   b3544          NaN  diagnosis
# 1 2019-08-06 12:57:01.062     respond   q5012          NaN  diagnosis
# 2 2019-08-06 12:58:13.432      submit   b3544          NaN  diagnosis
# 3 2019-08-06 12:58:59.668       enter   b3238          NaN  diagnosis
# 4 2019-08-06 13:00:01.774     respond   q4706          NaN  diagnosis
#
#   user_answer platform  user_iD
# 0        None   mobile        1
# 1           b   mobile        1
# 2        None   mobile        1
# 3        None   mobile        1
# 4           c   mobile        1

# %%
KT4['timestamp'].unique()
# Out:
# array(['2019-08-06T12:56:30.868000000', '2019-08-06T12:57:01.062000000',
#        '2019-08-06T12:58:13.432000000', ...,
#        '2019-09-20T07:35:54.949000000', '2019-09-20T07:36:32.328000000',
#                                  'NaT'], dtype='datetime64[ns]')

# %%
pd.value_counts(KT4['timestamp'])
# Out:
# 2019-11-20 22:02:44.000    21
# 2019-11-20 22:14:35.000    19
# 2019-11-21 12:53:37.000    19
# 2019-11-21 12:54:39.000    19
# 2019-11-16 03:01:35.000    18
#                            ..
# 2019-11-11 14:45:17.000     1
# 2019-08-04 12:10:08.928     1
# 2018-11-12 13:01:48.986     1
# 2019-03-20 14:58:12.627     1
# 2019-08-22 03:20:32.377     1
# Name: timestamp, Length: 29837754, dtype: int64

# %%
pd.value_counts(KT1['timestamp'])
# Out:
# 2019-11-20 22:02:44.000    21
# 2019-11-20 22:14:35.000    19
# 2019-11-21 12:54:39.000    19
# 2019-11-21 12:53:37.000    19
# 2019-11-16 03:01:35.000    18
#                            ..
# 2019-09-07 05:43:24.683     1
# 2019-02-19 10:55:18.510     1
# 2019-04-23 02:32:19.163     1
# 2019-01-13 15:04:17.881     1
# 2019-08-22 03:20:32.377     1
# Name: timestamp, Length: 29837754, dtype: int64

# %%
KT4.to_feather('KT4_New.ftr')
KT1.to_feather('KT1_New.ftr')
questions.to_csv('questions_new.csv')
lectures.to_csv('lectures_new.csv')

# %%
K1= pd.read_feather('KT1_New.ftr')
K1.head()
# Out:
#                 timestamp  solving_id question_id user_answer  elapsed_time  \
# 0 2019-08-06 12:56:30.868           1       q5012           b         38000
# 1 2019-08-06 12:57:01.062           2       q4706           c         24000
# 2 2019-08-06 12:58:13.432           3       q4366           b         68000
# 3 2019-08-06 12:58:59.668           4       q4829           a         42000
# 4 2019-08-06 13:00:01.774           5       q6528           b         59000
#
#    user_iD
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
K4= pd.read_feather('KT4_New.ftr')
K4.head()
# Out:
#                 timestamp action_type item_id  cursor_time     source  \
# 0 2019-08-06 12:56:30.868       enter   b3544          NaN  diagnosis
# 1 2019-08-06 12:57:01.062     respond   q5012          NaN  diagnosis
# 2 2019-08-06 12:58:13.432      submit   b3544          NaN  diagnosis
# 3 2019-08-06 12:58:59.668       enter   b3238          NaN  diagnosis
# 4 2019-08-06 13:00:01.774     respond   q4706          NaN  diagnosis
#
#   user_answer platform  user_iD
# 0        None   mobile        1
# 1           b   mobile        1
# 2        None   mobile        1
# 3        None   mobile        1
# 4           c   mobile        1

# %%
Ques = pd.read_csv('questions_new.csv')
Ques.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags              deployed_at
# 0   1;2;179;181  2019-05-17 11:40:17.098
# 1      15;2;182  2019-05-17 11:40:19.720
# 2  14;2;179;183  2019-05-17 11:40:22.784
# 3   9;2;179;184  2019-05-17 11:40:25.357
# 4   8;2;179;181  2019-05-17 11:40:28.439

# %%
pd.value_counts(Ques['part'])
# Out:
# 5    5703
# 2    1662
# 7    1402
# 6    1335
# 3    1266
# 4    1158
# 1     643
# Name: part, dtype: int64

# %%
Lec = pd.read_csv('lectures_new.csv')
Lec.head()
# Out:
#    Unnamed: 0 lecture_id  part  tags  video_length              deployed_at
# 0           0       l520     5   142            -1  1969-12-31 23:59:59.999
# 1           1       l592     6   142            -1  1969-12-31 23:59:59.999
# 2           2      l1259     1   222        359000  2019-10-07 05:05:29.123
# 3           3      l1260     1   220        487000  2019-10-07 05:05:38.105
# 4           4      l1261     1   221        441000  2019-10-07 05:05:43.162

# %%
del Ques['Unnamed: 0']
del Lec['Unnamed: 0']

# %%
Ques.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                deployed_at
# 0  2019-05-17 11:40:17.098
# 1  2019-05-17 11:40:19.720
# 2  2019-05-17 11:40:22.784
# 3  2019-05-17 11:40:25.357
# 4  2019-05-17 11:40:28.439

# %%
Lec.head()
# Out:
#   lecture_id  part  tags  video_length              deployed_at
# 0       l520     5   142            -1  1969-12-31 23:59:59.999
# 1       l592     6   142            -1  1969-12-31 23:59:59.999
# 2      l1259     1   222        359000  2019-10-07 05:05:29.123
# 3      l1260     1   220        487000  2019-10-07 05:05:38.105
# 4      l1261     1   221        441000  2019-10-07 05:05:43.162

# %%
Ques.to_csv('questions.csv')
Lec.to_csv('lectures.csv')

# %%
Question = pd.read_csv('questions.csv')
Lecture = pd.read_csv('lectures.csv')

# %%
A= Lec(['lecture_id' ,'part' , 'tags' , 'video_length' , 'deployed_at' ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bb6115f70851> in <module>
# ----> 1 A= Lec(['lecture_id' ,'part' , 'tags' , 'video_length' , 'deployed_at' ])
#
# TypeError: 'DataFrame' object is not callable

# %%
A = pd.merge(Question , Lecture)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-77783e847f1a> in <module>
# ----> 1 A = pd.merge(Question , Lecture)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
# ...

# %%
A= pd.concat(Question , Lecture)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-18c9bdc7c1a9> in <module>
# ----> 1 A= pd.concat(Question , Lecture)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     308         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     309             raise TypeError(
# --> 310                 "first argument must be an iterable of pandas "
# ...

# %%
A= pd.concat([Question, Lecture], axis=1)

# %%
A.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags              deployed_at  Unnamed: 0 lecture_id  part   tags  \
# 0   1;2;179;181  2019-05-17 11:40:17.098         0.0       l520   5.0  142.0
# 1      15;2;182  2019-05-17 11:40:19.720         1.0       l592   6.0  142.0
# 2  14;2;179;183  2019-05-17 11:40:22.784         2.0      l1259   1.0  222.0
# 3   9;2;179;184  2019-05-17 11:40:25.357         3.0      l1260   1.0  220.0
# 4   8;2;179;181  2019-05-17 11:40:28.439         4.0      l1261   1.0  221.0
#
#    video_length              deployed_at
# ...

# %%
Question.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags              deployed_at
# 0   1;2;179;181  2019-05-17 11:40:17.098
# 1      15;2;182  2019-05-17 11:40:19.720
# 2  14;2;179;183  2019-05-17 11:40:22.784
# 3   9;2;179;184  2019-05-17 11:40:25.357
# 4   8;2;179;181  2019-05-17 11:40:28.439

# %%
Lecture.head()
# Out:
#    Unnamed: 0 lecture_id  part  tags  video_length              deployed_at
# 0           0       l520     5   142            -1  1969-12-31 23:59:59.999
# 1           1       l592     6   142            -1  1969-12-31 23:59:59.999
# 2           2      l1259     1   222        359000  2019-10-07 05:05:29.123
# 3           3      l1260     1   220        487000  2019-10-07 05:05:38.105
# 4           4      l1261     1   221        441000  2019-10-07 05:05:43.162

# %%
# Or rename the existing DataFrame (rather than creating a copy) 
Question.rename(columns={'deployed_at': 'deployed'}, inplace=True)

# %%
Question.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags                 deployed
# 0   1;2;179;181  2019-05-17 11:40:17.098
# 1      15;2;182  2019-05-17 11:40:19.720
# 2  14;2;179;183  2019-05-17 11:40:22.784
# 3   9;2;179;184  2019-05-17 11:40:25.357
# 4   8;2;179;181  2019-05-17 11:40:28.439

# %%
# Or rename the existing DataFrame (rather than creating a copy) 
Question.rename(columns={'Unnamed: 0': 'Unnamed: 1'}, inplace=True)

# %%
Question.head()
# Out:
#    Unnamed: 1 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags                 deployed
# 0   1;2;179;181  2019-05-17 11:40:17.098
# 1      15;2;182  2019-05-17 11:40:19.720
# 2  14;2;179;183  2019-05-17 11:40:22.784
# 3   9;2;179;184  2019-05-17 11:40:25.357
# 4   8;2;179;181  2019-05-17 11:40:28.439

# %%
del Question['Unnamed: 1']
del Lecture['Unnamed: 0']

# %%
Question.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                   deployed
# 0  2019-05-17 11:40:17.098
# 1  2019-05-17 11:40:19.720
# 2  2019-05-17 11:40:22.784
# 3  2019-05-17 11:40:25.357
# 4  2019-05-17 11:40:28.439

# %%
B= pd.concat([Question, Lecture], axis=1)
B.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                   deployed lecture_id  part   tags  video_length  \
# 0  2019-05-17 11:40:17.098       l520   5.0  142.0          -1.0
# 1  2019-05-17 11:40:19.720       l592   6.0  142.0          -1.0
# 2  2019-05-17 11:40:22.784      l1259   1.0  222.0      359000.0
# 3  2019-05-17 11:40:25.357      l1260   1.0  220.0      487000.0
# 4  2019-05-17 11:40:28.439      l1261   1.0  221.0      441000.0
#
#                deployed_at
# 0  1969-12-31 23:59:59.999
# 1  1969-12-31 23:59:59.999
# 2  2019-10-07 05:05:29.123
# ...

# %%
del B['deployed']

# %%
B.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#   lecture_id  part   tags  video_length              deployed_at
# 0       l520   5.0  142.0          -1.0  1969-12-31 23:59:59.999
# 1       l592   6.0  142.0          -1.0  1969-12-31 23:59:59.999
# 2      l1259   1.0  222.0      359000.0  2019-10-07 05:05:29.123
# 3      l1260   1.0  220.0      487000.0  2019-10-07 05:05:38.105
# 4      l1261   1.0  221.0      441000.0  2019-10-07 05:05:43.162

# %%
del B['tags']

# %%
B.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part lecture_id  part  \
# 0          q1        b1             e1              b     1       l520   5.0
# 1          q2        b2             e2              a     1       l592   6.0
# 2          q3        b3             e3              b     1      l1259   1.0
# 3          q4        b4             e4              b     1      l1260   1.0
# 4          q5        b5             e5              c     1      l1261   1.0
#
#    video_length              deployed_at
# 0          -1.0  1969-12-31 23:59:59.999
# 1          -1.0  1969-12-31 23:59:59.999
# 2      359000.0  2019-10-07 05:05:29.123
# 3      487000.0  2019-10-07 05:05:38.105
# 4      441000.0  2019-10-07 05:05:43.162

# %%
Question.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                   deployed
# 0  2019-05-17 11:40:17.098
# 1  2019-05-17 11:40:19.720
# 2  2019-05-17 11:40:22.784
# 3  2019-05-17 11:40:25.357
# 4  2019-05-17 11:40:28.439

# %%
Lecture.head()
# Out:
#   lecture_id  part  tags  video_length              deployed_at
# 0       l520     5   142            -1  1969-12-31 23:59:59.999
# 1       l592     6   142            -1  1969-12-31 23:59:59.999
# 2      l1259     1   222        359000  2019-10-07 05:05:29.123
# 3      l1260     1   220        487000  2019-10-07 05:05:38.105
# 4      l1261     1   221        441000  2019-10-07 05:05:43.162

# %%
Question.rename(columns={'deployed': 'deployed_Q'}, inplace=True)
Lecture.rename(columns={'deployed_at': 'deployed_L'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-580d1ea31446> in <module>
# ----> 1 Question.rename(columns={'deployed': 'deployed_Q'}, inplace=True)
#       2 Lecture.rename(columns={'deployed_at': 'deployed_L'}, inplace=True)
#
# NameError: name 'Question' is not defined

# %%
questions_A = pd.read_csv('questions.csv')
lectures_A = pd.read_csv('lectures.csv')

# %%
questions_A.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags              deployed_at
# 0   1;2;179;181  2019-05-17 11:40:17.098
# 1      15;2;182  2019-05-17 11:40:19.720
# 2  14;2;179;183  2019-05-17 11:40:22.784
# 3   9;2;179;184  2019-05-17 11:40:25.357
# 4   8;2;179;181  2019-05-17 11:40:28.439

# %%
lectures_A.head()
# Out:
#    Unnamed: 0 lecture_id  part  tags  video_length              deployed_at
# 0           0       l520     5   142            -1  1969-12-31 23:59:59.999
# 1           1       l592     6   142            -1  1969-12-31 23:59:59.999
# 2           2      l1259     1   222        359000  2019-10-07 05:05:29.123
# 3           3      l1260     1   220        487000  2019-10-07 05:05:38.105
# 4           4      l1261     1   221        441000  2019-10-07 05:05:43.162

# %%
questions.rename(columns={'deployed_at': 'deployed_Q'}, inplace=True)
lectures.rename(columns={'deployed_at': 'deployed_L'}, inplace=True)

# %%
questions.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#       deployed_Q
# 0  1558093217098
# 1  1558093219720
# 2  1558093222784
# 3  1558093225357
# 4  1558093228439

# %%
lectures.head()
# Out:
#   lecture_id  part  tags  video_length     deployed_L
# 0       l520     5   142            -1             -1
# 1       l592     6   142            -1             -1
# 2      l1259     1   222        359000  1570424729123
# 3      l1260     1   220        487000  1570424738105
# 4      l1261     1   221        441000  1570424743162

# %%
C= pd.concat([questions, lectures], axis=1)
C.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#       deployed_Q lecture_id  part   tags  video_length    deployed_L
# 0  1558093217098       l520   5.0  142.0          -1.0 -1.000000e+00
# 1  1558093219720       l592   6.0  142.0          -1.0 -1.000000e+00
# 2  1558093222784      l1259   1.0  222.0      359000.0  1.570425e+12
# 3  1558093225357      l1260   1.0  220.0      487000.0  1.570425e+12
# 4  1558093228439      l1261   1.0  221.0      441000.0  1.570425e+12

# %%
C.to_csv('Content.csv')

# %%
Content = pd.read_csv('Content.csv')
Content.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags     deployed_Q lecture_id  part.1  tags.1  video_length  \
# 0   1;2;179;181  1558093217098       l520     5.0   142.0          -1.0
# 1      15;2;182  1558093219720       l592     6.0   142.0          -1.0
# 2  14;2;179;183  1558093222784      l1259     1.0   222.0      359000.0
# 3   9;2;179;184  1558093225357      l1260     1.0   220.0      487000.0
# 4   8;2;179;181  1558093228439      l1261     1.0   221.0      441000.0
#
#      deployed_L
# 0 -1.000000e+00
# 1 -1.000000e+00
# 2  1.570425e+12
# 3  1.570425e+12
# ...

# %%
del Content['Unnamed: 0']

# %%
Content.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#       deployed_Q lecture_id  part.1  tags.1  video_length    deployed_L
# 0  1558093217098       l520     5.0   142.0          -1.0 -1.000000e+00
# 1  1558093219720       l592     6.0   142.0          -1.0 -1.000000e+00
# 2  1558093222784      l1259     1.0   222.0      359000.0  1.570425e+12
# 3  1558093225357      l1260     1.0   220.0      487000.0  1.570425e+12
# 4  1558093228439      l1261     1.0   221.0      441000.0  1.570425e+12

# %%
Content['deployed_Q'] = pd.to_datetime(Content['deployed_Q'],unit='ms')
Content['deployed_L'] = pd.to_datetime(Content['deployed_L'],unit='ms')
Content.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                deployed_Q lecture_id  part.1  tags.1  video_length  \
# 0 2019-05-17 11:40:17.098       l520     5.0   142.0          -1.0
# 1 2019-05-17 11:40:19.720       l592     6.0   142.0          -1.0
# 2 2019-05-17 11:40:22.784      l1259     1.0   222.0      359000.0
# 3 2019-05-17 11:40:25.357      l1260     1.0   220.0      487000.0
# 4 2019-05-17 11:40:28.439      l1261     1.0   221.0      441000.0
#
#                deployed_L
# 0 1969-12-31 23:59:59.999
# 1 1969-12-31 23:59:59.999
# 2 2019-10-07 05:05:29.123
# ...

# %%
Content.to_csv('Content.csv')

# %%
D = pd.read_csv('Content.csv')

# %%
D.head()
# Out:
#    Unnamed: 0 question_id bundle_id explanation_id correct_answer  part  \
# 0           0          q1        b1             e1              b     1
# 1           1          q2        b2             e2              a     1
# 2           2          q3        b3             e3              b     1
# 3           3          q4        b4             e4              b     1
# 4           4          q5        b5             e5              c     1
#
#            tags               deployed_Q lecture_id  part.1  tags.1  \
# 0   1;2;179;181  2019-05-17 11:40:17.098       l520     5.0   142.0
# 1      15;2;182  2019-05-17 11:40:19.720       l592     6.0   142.0
# 2  14;2;179;183  2019-05-17 11:40:22.784      l1259     1.0   222.0
# 3   9;2;179;184  2019-05-17 11:40:25.357      l1260     1.0   220.0
# 4   8;2;179;181  2019-05-17 11:40:28.439      l1261     1.0   221.0
#
#    video_length               deployed_L
# 0          -1.0  1969-12-31 23:59:59.999
# ...

# %%
D.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                 deployed_Q lecture_id  part.1  tags.1  video_length  \
# 0  2019-05-17 11:40:17.098       l520     5.0   142.0          -1.0
# 1  2019-05-17 11:40:19.720       l592     6.0   142.0          -1.0
# 2  2019-05-17 11:40:22.784      l1259     1.0   222.0      359000.0
# 3  2019-05-17 11:40:25.357      l1260     1.0   220.0      487000.0
# 4  2019-05-17 11:40:28.439      l1261     1.0   221.0      441000.0
#
#                 deployed_L
# 0  1969-12-31 23:59:59.999
# 1  1969-12-31 23:59:59.999
# ...

# %%
D.to_feather('Content.ftr')

# %%
E= pd.read_feather('Content.ftr')

# %%
E.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                 deployed_Q lecture_id  part.1  tags.1  video_length  \
# 0  2019-05-17 11:40:17.098       l520     5.0   142.0          -1.0
# 1  2019-05-17 11:40:19.720       l592     6.0   142.0          -1.0
# 2  2019-05-17 11:40:22.784      l1259     1.0   222.0      359000.0
# 3  2019-05-17 11:40:25.357      l1260     1.0   220.0      487000.0
# 4  2019-05-17 11:40:28.439      l1261     1.0   221.0      441000.0
#
#                 deployed_L
# 0  1969-12-31 23:59:59.999
# 1  1969-12-31 23:59:59.999
# ...

# %%
E.rename(columns={'part.1': 'part_L' , 'tags.1': 'tags_L'}, inplace=True)

# %%
E.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                 deployed_Q lecture_id  part_L  tags_L  video_length  \
# 0  2019-05-17 11:40:17.098       l520     5.0   142.0          -1.0
# 1  2019-05-17 11:40:19.720       l592     6.0   142.0          -1.0
# 2  2019-05-17 11:40:22.784      l1259     1.0   222.0      359000.0
# 3  2019-05-17 11:40:25.357      l1260     1.0   220.0      487000.0
# 4  2019-05-17 11:40:28.439      l1261     1.0   221.0      441000.0
#
#                 deployed_L
# 0  1969-12-31 23:59:59.999
# 1  1969-12-31 23:59:59.999
# ...

# %%
E.to_feather('Content.ftr')
F= pd.read_feather('Content.ftr')

# %%
F.head()
# Out:
#   question_id bundle_id explanation_id correct_answer  part          tags  \
# 0          q1        b1             e1              b     1   1;2;179;181
# 1          q2        b2             e2              a     1      15;2;182
# 2          q3        b3             e3              b     1  14;2;179;183
# 3          q4        b4             e4              b     1   9;2;179;184
# 4          q5        b5             e5              c     1   8;2;179;181
#
#                 deployed_Q lecture_id  part_L  tags_L  video_length  \
# 0  2019-05-17 11:40:17.098       l520     5.0   142.0          -1.0
# 1  2019-05-17 11:40:19.720       l592     6.0   142.0          -1.0
# 2  2019-05-17 11:40:22.784      l1259     1.0   222.0      359000.0
# 3  2019-05-17 11:40:25.357      l1260     1.0   220.0      487000.0
# 4  2019-05-17 11:40:28.439      l1261     1.0   221.0      441000.0
#
#                 deployed_L
# 0  1969-12-31 23:59:59.999
# 1  1969-12-31 23:59:59.999
# ...
