# %% [markdown]
# # EDNET DATA KT4

# %% [markdown]
# 1: Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
# Adjusting column and row numbers to be shown
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import feather

# %% [markdown]
# 2: Converting different .csv files into a single file with user_ID

# %%
import glob

path = r'C:/Users/user1/Desktop/CONDENSE DATASET/KT4' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for i,filename in enumerate (all_files):
    
    df = pd.read_csv(filename, ',' ,index_col=None, header=0).assign(user_iD=filename.split("\\u")[-1].split(".")[0])
    
    
    li.append(df)

# %% [markdown]
# 3: Making a DataFrame

# %%
data = pd.concat(li, axis=0, ignore_index=True)
df = data.copy()

# %%
df.head()
# Out:
#        timestamp action_type item_id  cursor_time     source user_answer  \
# 0  1565096151269       enter   b3544          NaN  diagnosis         NaN
# 1  1565096187972     respond   q5012          NaN  diagnosis           b
# 2  1565096194904      submit   b3544          NaN  diagnosis         NaN
# 3  1565096195001       enter   b3238          NaN  diagnosis         NaN
# 4  1565096218682     respond   q4706          NaN  diagnosis           c
#
#   platform user_iD
# 0   mobile       1
# 1   mobile       1
# 2   mobile       1
# 3   mobile       1
# 4   mobile       1

# %%
df.isnull().sum()
# Out:
# timestamp              0
# action_type            0
# item_id                0
# cursor_time     94106627
# source             27933
# user_answer    103152909
# platform           27933
# user_iD                0
# dtype: int64

# %%
df.tail()
# Out:
#                timestamp action_type item_id  cursor_time  source user_answer  \
# 131375190  1568964975390       enter   b3819          NaN  sprint         NaN
# 131375191  1568964992921     respond   q5287          NaN  sprint           c
# 131375192  1568964996503      submit   b3819          NaN  sprint         NaN
# 131375193  1568964996572       enter   e3819          NaN  sprint         NaN
# 131375194  1568965006334        quit   e3819          NaN  sprint         NaN
#
#           platform user_iD
# 131375190   mobile    9998
# 131375191   mobile    9998
# 131375192   mobile    9998
# 131375193   mobile    9998
# 131375194   mobile    9998

# %%
df["user_iD"] = df["user_iD"].astype(str).astype(int)
print(df.dtypes)
# Out:
# timestamp        int64
# action_type     object
# item_id         object
# cursor_time    float64
# source          object
# user_answer     object
# platform        object
# user_iD          int32
# dtype: object

# %% [markdown]
# Converting this into a feather

# %%
df.to_feather('KT4.ftr')

# %%
KT4= pd.read_feather('KT4.ftr')

# %%
KT4.head()
# Out:
#        timestamp action_type item_id  cursor_time     source user_answer  \
# 0  1565096151269       enter   b3544          NaN  diagnosis        None
# 1  1565096187972     respond   q5012          NaN  diagnosis           b
# 2  1565096194904      submit   b3544          NaN  diagnosis        None
# 3  1565096195001       enter   b3238          NaN  diagnosis        None
# 4  1565096218682     respond   q4706          NaN  diagnosis           c
#
#   platform  user_iD
# 0   mobile        1
# 1   mobile        1
# 2   mobile        1
# 3   mobile        1
# 4   mobile        1

# %%
print(KT4.dtypes)
# Out:
# timestamp        int64
# action_type     object
# item_id         object
# cursor_time    float64
# source          object
# user_answer     object
# platform        object
# user_iD          int32
# dtype: object

# %%
KT4['user_iD'].unique()
# Out:
# array([   1,   10,  100, ..., 9994, 9995, 9998])

# %%
A= pd.value_counts(KT4['user_iD'], dropna=False)
len(A)
# Out:
# 289886

# %%
KT4['user_iD'].value_counts()[:30].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[0:30].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[30:60].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[60:90].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[90:120].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[120:150].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[150:180].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[180:210].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[220:240].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[240:270].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[270:300].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[300:330].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[330:360].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[360:390].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[390:420].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[420:450].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[450:470].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[470:500].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[500:530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[530:560].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[560:590].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[590:620].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[620:650].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[650:680].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[680:710].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[710:740].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[1050:1080].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[2000:2030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[3000:3030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[4000:4030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[5000:5030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[6000:6030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[9000:9030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[15000:15030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[17000:17030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[20000:20030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[25000:25030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[30000:30030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[35000:35030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[40000:40030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[45000:45030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[50000:50030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[55000:55030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[60000:60030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[70000:70030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[80000:80030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[90000:90030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[100000:100030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[100100:100130].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[100500:100530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[101500:101530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[102500:102530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[109500:109530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[110000:110030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[120000:120030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[130000:130030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[150000:150030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[200000:200030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[250000:250030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[280000:280030].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[280500:280530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[282500:282530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[285500:285530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[286500:286530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[288500:288530].plot(kind='bar')

# %%
KT4['user_iD'].value_counts()[289500:289530].plot(kind='bar')
